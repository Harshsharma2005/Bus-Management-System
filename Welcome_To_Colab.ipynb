# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshsharma2005/Bus-Management-System/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
import numpy as np
import IPython.display as display
from matplotlib import pyplot as plt
import io
import base64

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

fig = plt.figure(figsize=(4, 3), facecolor='w')
plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)
plt.title("Sample Visualization", fontsize=10)

data = io.BytesIO()
plt.savefig(data)
image = F"data:image/png;base64,{base64.b64encode(data.getvalue()).decode()}"
alt = "Sample Visualization"
display.display(display.Markdown(F"""![{alt}]({image})"""))
plt.close(fig)
# Out:
# ![Sample Visualization](data:image/png;base64,...)

# %%
import pandas as pd

data = {'Name':['John','Alice','Bob','Eve','Cherie'],
'Age':[25,30,22,35,28],
'Gender':['Male','Female','Male','Female','Male'],
'Salary':[55000,55000,40000,70000,48000]}

df = pd.DataFrame(data)
# Display the entire DataFrame
print(df)
# Out:
#      Name  Age  Gender  Salary
# 0    John   25    Male   55000
# 1   Alice   30  Female   55000
# 2     Bob   22    Male   40000
# 3     Eve   35  Female   70000
# 4  Cherie   28    Male   48000

# %%
# Access the 'Age column
age_column = df['Age']
print(age_column)
# Out:
# 0    25
# 1    30
# 2    22
# 3    35
# 4    28
# Name: Age, dtype: int64

# %%
# Access the row at the index 1(second row)
second_row = df.iloc[1]
print(second_row)
# Out:
# Name       Alice
# Age           30
# Gender    Female
# Salary     55000
# Name: 1, dtype: object

# %%
# Access the first three row and the name and age
subset = df.loc[0:2,['Name','Age']]
print(subset)
# Out:
#     Name  Age
# 0   John   25
# 1  Alice   30
# 2    Bob   22

# %%
# Access rows where 'Age' is greater than 25
filtered_data = df[df["Age"]>25]
print(filtered_data)
# Out:
#      Name  Age  Gender  Salary
# 1   Alice   30  Female   55000
# 3     Eve   35  Female   70000
# 4  Cherie   28    Male   48000

# %%
# Access the 'Salary' of the row and with label 2
salary_at_index_2 = df.at[2,'Salary']
print(salary_at_index_2)
# Out:
# 40000

# %%
import pandas as pd

player_list = [['M.S.Dhoni',36,75,5428000],
               ['A.B.D Villers',38,74,3428000],
               ['V.Kholi',31,70,8428000],
               ['S.Smith',34,80,4438000],
               ['C.Gayle',40,100,4528000],
               ['J.Root',33,72,7028000],
               ['K.Perterson',42,85,2528000]]

df = pd.DataFrame(player_list, columns=['Name','Age','Weight','Salary'])
print(df)
# Out:
#             Name  Age  Weight   Salary
# 0      M.S.Dhoni   36      75  5428000
# 1  A.B.D Villers   38      74  3428000
# 2        V.Kholi   31      70  8428000
# 3        S.Smith   34      80  4438000
# 4        C.Gayle   40     100  4528000
# 5         J.Root   33      72  7028000
# 6    K.Perterson   42      85  2528000

# %%
df1 = df.iloc[0:4]
print(df1)
# Out:
#             Name  Age  Weight   Salary
# 0      M.S.Dhoni   36      75  5428000
# 1  A.B.D Villers   38      74  3428000
# 2        V.Kholi   31      70  8428000
# 3        S.Smith   34      80  4438000

# %%
value = df.iloc[2,3]
print("Specific Cell Value", value)
# Out:
# Specific Cell Value 8428000

# %%
data = df[df['Age']>35].iloc[:,:]
print("\nFiltered Data based on Age > 35:\n", data)
# Out:
# Filtered Data based on Age > 35:
#              Name  Age  Weight   Salary
# 0      M.S.Dhoni   36      75  5428000
# 1  A.B.D Villers   38      74  3428000
# 4        C.Gayle   40     100  4528000
# 6    K.Perterson   42      85  2528000

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# Initialize scalers
min_max = MinMaxScaler()
standard = StandardScaler()

# Reshaping Age for the scaler
age_data = df[['Age']]

# Apply Scalling
df['Age_MnMax'] = min_max.fit_transform(age_data)
df['Age_Standardized'] = standard.fit_transform(age_data)

print("\nFinal Cleaned and Scaled Data:\n", df)
# Out:
# Final Cleaned and Scaled Data:
#              Name  Age  Weight   Salary  Age_MnMax  Age_Standardized
# 0      M.S.Dhoni   36      75  5428000   0.454545         -0.078206
# 1  A.B.D Villers   38      74  3428000   0.636364          0.469237
# 2        V.Kholi   31      70  8428000   0.000000         -1.446814
# 3        S.Smith   34      80  4438000   0.272727         -0.625650
# 4        C.Gayle   40     100  4528000   0.818182          1.016680
# 5         J.Root   33      72  7028000   0.181818         -0.899371
# 6    K.Perterson   42      85  2528000   1.000000          1.564124

# %%
data = {"Marks":[50,60,70,80]}

df = pd.DataFrame(data)
# Out:
#   File "/tmp/ipykernel_1867/1552932896.py", line 1
#     data = {Marks"}
#                  ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
pip install folium

# %%
import folium

# Create base map
m = folium.Map(location=[28.6139,77.2090],zoom_start=6)

# Add Marker
folium.Marker(
    location=[28.6139, 77.2090],
    popup = "New Delhi"
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
pip install geopy

# %%
import pandas as pd

# Creating a sample geospatial dataset
data = {
    'Store_ID': [101, 102, 103, 104, 105],
    'City': ['Delhi', 'Mumbai', 'Bangolore', 'Chennai', 'Kolkata'],
    'Latitude': [28.6139, 19.0760, 12.9716, 13.0827, 22.5726],
    'Longtude': [77.2090, 72.8777, 77.5946, 80.2707, 88.3639],
    'Sales_Units': [500, 850, 620, 410, 580]
}

df = pd.DataFrame(data)
df.to_csv('store_location.csv',index=False)
print("Dataset 'Store_location.csv' created sucessfully!")
# Out:
# Dataset 'Store_location.csv' created sucessfully!
